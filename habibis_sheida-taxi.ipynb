# %%
#Question1: minimum and maximum values for pickup_date:

import csv, datetime

data = 'trip_data_6.csv'
f = open(data, 'r')
reader = csv.reader(f)
n = 0
minval = None
maxval = None
n = 0
for row in reader:
    if n > 0:
        dto = None
        dts = row[5]
        try:
            dto= datetime.datetime.strptime(dts,"%Y-%m-%d %H:%M:%S")
        except Exception as e:
            print(e)
        if dto is not None:
            if maxval is None or dto > maxval:
                maxval = dto
            elif minval is None or dto < minval:
                minval = dto
    n+=1
print('min_pickup_date:', minval, ', max_pickup_date:' , maxval)
# Out:
# min_pickup_date: 2013-06-01 00:00:00 , max_pickup_date: 2013-06-30 23:59:56

# %%
#Question1: minimum and maximum values for dropoff_date:
data = 'trip_data_6.csv'

f = open(data, 'r')
reader = csv.reader(f)
n = 0
minval = None
maxval = None
n = 0
for row in reader:
    if n > 0:
        dto = None
        dts = row[6]
        try:
            dto= datetime.datetime.strptime(dts,"%Y-%m-%d %H:%M:%S")
        except Exception as e:
            print(e)
        if dto is not None:
            if maxval is None or dto > maxval:
                maxval = dto
            elif minval is None or dto < minval:
                minval = dto
    n+=1
print('min_dropoff_date:', minval, ', max_dropoff_date:' , maxval)
# Out:
# min_dropoff_date: 2013-03-22 08:04:00 , max_dropoff_date: 2013-07-01 01:14:24

# %%
#Question 1: number of rows in data set:

import csv, datetime

data = 'trip_data_6.csv'

f = open(data, 'r')
reader = csv.reader(f)
n = 0
for row in reader:
    if n % 50000 == 0:
        print(n)
    n+=1

print(n)
# Out:
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# 300000
# 350000
# 400000
# 450000
# 500000
# 550000
# 600000
# 650000
# 700000
# 750000
# 800000
# 850000
# 900000
# 950000
# 1000000
# 1050000
# 1100000
# 1150000
# 1200000
# 1250000
# 1300000
# 1350000
# 1400000
# 1450000
# 1500000
# 1550000
# 1600000
# 1650000
# 1700000
# 1750000
# 1800000
# 1850000
# 1900000
# 1950000
# 2000000
# 2050000
# 2100000
# 2150000
# 2200000
# 2250000
# 2300000
# 2350000
# 2400000
# 2450000
# 2500000
# 2550000
# 2600000
# 2650000
# 2700000
# 2750000
# 2800000
# 2850000
# 2900000
# 2950000
# 3000000
# 3050000
# 3100000
# 3150000
# 3200000
# 3250000
# 3300000
# 3350000
# 3400000
# 3450000
# 3500000
# 3550000
# 3600000
# 3650000
# 3700000
# 3750000
# 3800000
# 3850000
# 3900000
# 3950000
# 4000000
# 4050000
# 4100000
# 4150000
# 4200000
# 4250000
# 4300000
# 4350000
# 4400000
# 4450000
# 4500000
# 4550000
# 4600000
# 4650000
# 4700000
# 4750000
# 4800000
# 4850000
# 4900000
# 4950000
# 5000000
# 5050000
# 5100000
# 5150000
# 5200000
# 5250000
# 5300000
# 5350000
# 5400000
# 5450000
# 5500000
# 5550000
# 5600000
# 5650000
# 5700000
# 5750000
# 5800000
# 5850000
# 5900000
# 5950000
# 6000000
# 6050000
# 6100000
# 6150000
# 6200000
# 6250000
# 6300000
# 6350000
# 6400000
# 6450000
# 6500000
# 6550000
# 6600000
# 6650000
# 6700000
# 6750000
# 6800000
# 6850000
# 6900000
# 6950000
# 7000000
# 7050000
# 7100000
# 7150000
# 7200000
# 7250000
# 7300000
# 7350000
# 7400000
# 7450000
# 7500000
# 7550000
# 7600000
# 7650000
# 7700000
# 7750000
# 7800000
# 7850000
# 7900000
# 7950000
# 8000000
# 8050000
# 8100000
# 8150000
# 8200000
# 8250000
# 8300000
# 8350000
# 8400000
# 8450000
# 8500000
# 8550000
# 8600000
# 8650000
# 8700000
# 8750000
# 8800000
# 8850000
# 8900000
# 8950000
# 9000000
# 9050000
# 9100000
# 9150000
# 9200000
# 9250000
# 9300000
# 9350000
# 9400000
# 9450000
# 9500000
# 9550000
# 9600000
# 9650000
# 9700000
# 9750000
# 9800000
# 9850000
# 9900000
# 9950000
# 10000000
# 10050000
# 10100000
# 10150000
# 10200000
# 10250000
# 10300000
# 10350000
# 10400000
# 10450000
# 10500000
# 10550000
# 10600000
# 10650000
# 10700000
# 10750000
# 10800000
# 10850000
# 10900000
# 10950000
# 11000000
# 11050000
# 11100000
# 11150000
# 11200000
# 11250000
# 11300000
# 11350000
# 11400000
# 11450000
# 11500000
# 11550000
# 11600000
# 11650000
# 11700000
# 11750000
# 11800000
# 11850000
# 11900000
# 11950000
# 12000000
# 12050000
# 12100000
# 12150000
# 12200000
# 12250000
# 12300000
# 12350000
# 12400000
# 12450000
# 12500000
# 12550000
# 12600000
# 12650000
# 12700000
# 12750000
# 12800000
# 12850000
# 12900000
# 12950000
# 13000000
# 13050000
# 13100000
# 13150000
# 13200000
# 13250000
# 13300000
# 13350000
# 13400000
# 13450000
# 13500000
# 13550000
# 13600000
# 13650000
# 13700000
# 13750000
# 13800000
# 13850000
# 13900000
# 13950000
# 14000000
# 14050000
# 14100000
# 14150000
# 14200000
# 14250000
# 14300000
# 14350000
# 14385457

# %%
# Question 2: 
# the field names:

import csv

data = 'trip_data_6.csv'

f = open(data, 'r')
reader = csv.reader(f)
n = 0
for row in reader:
    print(row)
    break

print(reader)
# Out:
# ['medallion', ' hack_license', ' vendor_id', ' rate_code', ' store_and_fwd_flag', ' pickup_datetime', ' dropoff_datetime', ' passenger_count', ' trip_time_in_secs', ' trip_distance', ' pickup_longitude', ' pickup_latitude', ' dropoff_longitude', ' dropoff_latitude']
# <_csv.reader object at 0x06E0DBC0>

# %%
# Question 3: 
# Sample data:

import csv

data = 'trip_data_6.csv'

f = open(data, 'r')
reader = csv.reader(f)
n = 0
for row in reader:
    print(row)
    n+=1
    if n > 5:
        break
# Out:
# ['medallion', ' hack_license', ' vendor_id', ' rate_code', ' store_and_fwd_flag', ' pickup_datetime', ' dropoff_datetime', ' passenger_count', ' trip_time_in_secs', ' trip_distance', ' pickup_longitude', ' pickup_latitude', ' dropoff_longitude', ' dropoff_latitude']
# ['D1C79CF706C80D3A1DC7FBCA6CD56E43', 'DAC7742E8F00034774098DBC6B4FF2B7', 'CMT', '1', 'N', '2013-06-03 00:02:12', '2013-06-03 00:10:07', '1', '474', '1.30', '-73.981583', '40.773529', '-73.981827', '40.782124']
# ['3567E8B49FEBFCBB587F1864D723D5C8', '430B8022563CDE1D51D44786DFD8D6CB', 'CMT', '1', 'N', '2013-06-03 00:03:03', '2013-06-03 00:19:27', '1', '982', '4.90', '-73.999565', '40.728367', '-73.952927', '40.729546']
# ['4220E1995D36A40DF34664AD33ED13F6', '48A1C9C9300AFC7BDBB718CE308EE45A', 'CMT', '2', 'N', '2013-06-03 00:01:30', '2013-06-03 00:28:11', '1', '1745', '17.70', '-73.788445', '40.641151', '-73.985451', '40.744194']
# ['440900089FF528A873424DED689C77A3', 'E6A63B40E565A8A03AF32E0B138F5EB1', 'CMT', '1', 'N', '2013-06-03 00:04:14', '2013-06-03 00:27:50', '1', '1415', '12.10', '-73.862816', '40.768875', '-74.008797', '40.738842']
# ['16129167D9E7B0846DBA3D04B78E1B8D', '227A03FC03CF429DFC9EAFF0AE8BA579', 'CMT', '1', 'N', '2013-06-03 00:04:53', '2013-06-03 00:10:46', '1', '353', '1.10', '-73.964905', '40.806881', '-73.962349', '40.794987']

# %%
# Question 5: 
# Geographic range:

import csv, datetime
data= 'trip_data_6.csv'

f= open(data, 'r')
reader = csv.reader(f)


n = 0


for row in reader:
    if n==1:
        lon_min = float(row[10])
        lat_min = float(row[11])
        lon_max = float(row[12])
        lat_max = float(row[13])
    elif n > 1:
        try:
            pick_lon = float(row[10])
            pick_lat = float(row[11])
            drop_lon = float(row[12])
            drop_lat = float(row[13])
        except Exception as e:
            print(e)
        
        if pick_lon!=0.0 and abs(pick_lon)<=180:
            if pick_lon < lon_min:
                lon_min = pick_lon
            if pick_lon > lon_max:
                lon_max = pick_lon
 
        if pick_lat!=0.0 and abs(pick_lat)<=90:
            if pick_lat < lat_min:
                lat_min = pick_lat
            if pick_lat > lat_max:
                lat_max = pick_lat

        if drop_lon!=0.0 and abs(drop_lon)<=180:
            if drop_lon < lon_min:
                lon_min = drop_lon
            if drop_lon > lon_max:
                lon_max = drop_lon

        if drop_lat!=0.0 and abs(drop_lat)<=90:
            if drop_lat < lat_min:
                lat_min = drop_lat
            if drop_lat > lat_max:
                lat_max = drop_lat
       
             
    if n % 50000 == 0:
        print(n)
    n+=1

print(n)

print('min_longitude:',lon_min, 'max_longitude:',lon_max, 'min_latitude:',lat_min, 'max_latitude:',lat_max)
print('Point 1:', lon_min, lat_min)
print('Point 2:', lon_min, lat_max)
print('Point 3:', lon_max, lat_max)
print('Point 4:', lon_max, lat_min)
# Out:
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# 300000
# 350000
# 400000
# 450000
# 500000
# 550000
# 600000
# 650000
# 700000
# 750000
# 800000
# 850000
# 900000
# 950000
# 1000000
# 1050000
# 1100000
# 1150000
# 1200000
# 1250000
# 1300000
# 1350000
# 1400000
# 1450000
# 1500000
# 1550000
# 1600000
# 1650000
# 1700000
# 1750000
# 1800000
# 1850000
# 1900000
# 1950000
# 2000000
# 2050000
# 2100000
# 2150000
# 2200000
# 2250000
# 2300000
# 2350000
# 2400000
# 2450000
# 2500000
# 2550000
# 2600000
# 2650000
# 2700000
# 2750000
# 2800000
# 2850000
# 2900000
# 2950000
# 3000000
# 3050000
# 3100000
# 3150000
# 3200000
# 3250000
# 3300000
# 3350000
# 3400000
# 3450000
# 3500000
# 3550000
# 3600000
# 3650000
# 3700000
# 3750000
# 3800000
# 3850000
# 3900000
# 3950000
# 4000000
# 4050000
# 4100000
# 4150000
# 4200000
# 4250000
# 4300000
# 4350000
# 4400000
# 4450000
# 4500000
# 4550000
# 4600000
# 4650000
# 4700000
# 4750000
# 4800000
# 4850000
# 4900000
# 4950000
# 5000000
# 5050000
# 5100000
# 5150000
# 5200000
# 5250000
# 5300000
# 5350000
# 5400000
# 5450000
# 5500000
# 5550000
# 5600000
# 5650000
# 5700000
# 5750000
# 5800000
# 5850000
# 5900000
# 5950000
# 6000000
# 6050000
# 6100000
# 6150000
# 6200000
# 6250000
# 6300000
# 6350000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 6400000
# could not convert string to float: ''
# could not convert string to float: ''
# 6450000
# 6500000
# 6550000
# could not convert string to float: ''
# 6600000
# 6650000
# 6700000
# 6750000
# 6800000
# 6850000
# 6900000
# could not convert string to float: ''
# 6950000
# 7000000
# could not convert string to float: ''
# 7050000
# 7100000
# 7150000
# could not convert string to float: ''
# 7200000
# 7250000
# 7300000
# 7350000
# 7400000
# 7450000
# 7500000
# 7550000
# 7600000
# 7650000
# 7700000
# 7750000
# 7800000
# 7850000
# 7900000
# 7950000
# 8000000
# 8050000
# 8100000
# 8150000
# 8200000
# 8250000
# 8300000
# 8350000
# 8400000
# 8450000
# could not convert string to float: ''
# could not convert string to float: ''
# 8500000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 8550000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 8600000
# could not convert string to float: ''
# could not convert string to float: ''
# 8650000
# could not convert string to float: ''
# 8700000
# could not convert string to float: ''
# 8750000
# 8800000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 8850000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 8900000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 8950000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 9000000
# 9050000
# 9100000
# 9150000
# 9200000
# 9250000
# 9300000
# 9350000
# 9400000
# 9450000
# 9500000
# 9550000
# 9600000
# 9650000
# could not convert string to float: ''
# could not convert string to float: ''
# 9700000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 9750000
# 9800000
# 9850000
# 9900000
# 9950000
# 10000000
# 10050000
# 10100000
# 10150000
# 10200000
# 10250000
# 10300000
# 10350000
# 10400000
# 10450000
# 10500000
# 10550000
# 10600000
# could not convert string to float: ''
# 10650000
# could not convert string to float: ''
# could not convert string to float: ''
# 10700000
# 10750000
# could not convert string to float: ''
# 10800000
# could not convert string to float: ''
# 10850000
# could not convert string to float: ''
# could not convert string to float: ''
# 10900000
# could not convert string to float: ''
# could not convert string to float: ''
# 10950000
# 11000000
# could not convert string to float: ''
# 11050000
# 11100000
# 11150000
# 11200000
# 11250000
# 11300000
# 11350000
# 11400000
# 11450000
# 11500000
# 11550000
# 11600000
# 11650000
# 11700000
# 11750000
# 11800000
# 11850000
# 11900000
# 11950000
# 12000000
# 12050000
# 12100000
# 12150000
# 12200000
# 12250000
# 12300000
# could not convert string to float: ''
# could not convert string to float: ''
# 12350000
# could not convert string to float: ''
# 12400000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 12450000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 12500000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 12550000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 12600000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 12650000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 12700000
# could not convert string to float: ''
# 12750000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 12800000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 12850000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 12900000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 12950000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 13000000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 13050000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 13100000
# could not convert string to float: ''
# could not convert string to float: ''
# 13150000
# could not convert string to float: ''
# 13200000
# 13250000
# 13300000
# could not convert string to float: ''
# 13350000
# 13400000
# 13450000
# 13500000
# could not convert string to float: ''
# 13550000
# 13600000
# could not convert string to float: ''
# could not convert string to float: ''
# 13650000
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# could not convert string to float: ''
# 13700000
# could not convert string to float: ''
# could not convert string to float: ''
# 13750000
# could not convert string to float: ''
# 13800000
# 13850000
# 13900000
# 13950000
# 14000000
# 14050000
# 14100000
# 14150000
# 14200000
# 14250000
# 14300000
# 14350000
# 14385457
# min_longitude: -156.64267 max_longitude: 171.93825 min_latitude: -74.408691 max_latitude: 79.827782
# Point 1: -156.64267 -74.408691
# Point 2: -156.64267 79.827782
# Point 3: 171.93825 79.827782
# Point 4: 171.93825 -74.408691

# %%
#Question 6:
#Average distance and finding points to show on the map.

from math import radians, cos, sin, asin, sqrt
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles. Determines return value units.
    return c * r
    
import csv, datetime
data= 'trip_data_6.csv'

f= open(data, 'r')
reader = csv.reader(f)

n = 0
distance=[]
sum_distance=0

for row in reader:
    if n==1:
        lon_min = float(row[10])
        lat_min = float(row[11])
        lon_max = float(row[12])
        lat_max = float(row[13])
    elif n > 1:
        try:
            pick_lon = float(row[10])
            pick_lat = float(row[11])
            drop_lon = float(row[12])
            drop_lat = float(row[13])
            if pick_lon!=0.0 and abs(pick_lon)<=180 and drop_lon!=0.0 and abs(drop_lon)<=180 and pick_lat!=0.0 and abs(pick_lat)<=90 and drop_lat!=0.0 and abs(drop_lat)<=90:
                dist=haversine(pick_lon, pick_lat, drop_lon, drop_lat)
                if dist<=100:
                    distance.append(dist)
                    sum_distance+=dist
        except Exception as e:
            print(e)           
    
    if n % 500000 == 0:
        print(n)
    n+=1

print('Average Distance=', sum_distance/(n-1), 'km')

import matplotlib.pyplot as plt
plt.hist(distance, bins=range(0,101,5), log=True)
plt.xlabel('Distance (km)')
plt.xticks(range(0,101,5))
plt.savefig('Distance_Distribution.jpg')
# Out:
# 0
# 500000
# 1000000
# 1500000
# 2000000
# 2500000
# 3000000
# 3500000
# 4000000
# 4500000
# 5000000
# 5500000
# 6000000
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# 6500000
# could not convert string to float:
# could not convert string to float:
# 7000000
# could not convert string to float:
# could not convert string to float:
# 7500000
# 8000000
# could not convert string to float:
# could not convert string to float:
# 8500000
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# 9000000
# 9500000
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# 10000000
# 10500000
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# 11000000
# could not convert string to float:
# 11500000
# 12000000
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# 12500000
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# 13000000
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# 13500000
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# could not convert string to float:
# 14000000
# Average Distance= 3.3888207386530746 km

# %%
#question 7
#Distinct vendor_id
import csv
data = 'trip_data_6.csv'

f = open(data, 'r')
reader = csv.reader(f)

vendor_id_distinct = {}

n=0
for row in reader:
    if n>0:
        k = row[2]
        if k in vendor_id_distinct:
            vendor_id_distinct[k] += 1
        else:
            vendor_id_distinct[k] = 1
        if n % 500000 == 0:
            print(n)
        
    n+=1

print(vendor_id_distinct)
# Out:
# 500000
# 1000000
# 1500000
# 2000000
# 2500000
# 3000000
# 3500000
# 4000000
# 4500000
# 5000000
# 5500000
# 6000000
# 6500000
# 7000000
# 7500000
# 8000000
# 8500000
# 9000000
# 9500000
# 10000000
# 10500000
# 11000000
# 11500000
# 12000000
# 12500000
# 13000000
# 13500000
# 14000000
# {'CMT': 7169244, 'VTS': 7216212}

# %%
#question 7
#Distinct store_and_fwd_flag:

import csv
data = 'trip_data_6.csv'

f = open(data, 'r')
reader = csv.reader(f)
store_and_fwd_flag = {}

i=0
n=0

for row in reader:
    if i>0:
        k = row[4]
        if k in store_and_fwd_flag:
            store_and_fwd_flag[k] += 1
        else:
            store_and_fwd_flag[k] = 1
        if n % 500000 == 0:
            print(n)
        n+=1
    i+=1

print(store_and_fwd_flag)
# Out:
# 0
# 500000
# 1000000
# 1500000
# 2000000
# 2500000
# 3000000
# 3500000
# 4000000
# 4500000
# 5000000
# 5500000
# 6000000
# 6500000
# 7000000
# 7500000
# 8000000
# 8500000
# 9000000
# 9500000
# 10000000
# 10500000
# 11000000
# 11500000
# 12000000
# 12500000
# 13000000
# 13500000
# 14000000
# {'N': 6906120, 'Y': 256624, '': 7222712}

# %%
#question 7
#Distinct rate_code:
import csv
data = 'trip_data_6.csv'

f = open(data, 'r')
reader = csv.reader(f)
rate_code = {}

i=0
n=0

for row in reader:
    if i>0:
        k = row[3]
        if k in rate_code:
             rate_code[k] += 1
        else:
             rate_code[k] = 1
        if n % 500000 == 0:
            print(n)
        n+=1
    i+=1

print(rate_code)
# Out:
# 0
# 500000
# 1000000
# 1500000
# 2000000
# 2500000
# 3000000
# 3500000
# 4000000
# 4500000
# 5000000
# 5500000
# 6000000
# 6500000
# 7000000
# 7500000
# 8000000
# 8500000
# 9000000
# 9500000
# 10000000
# 10500000
# 11000000
# 11500000
# 12000000
# 12500000
# 13000000
# 13500000
# 14000000
# {'1': 14053347, '2': 257221, '5': 39362, '3': 22131, '4': 6348, '6': 178, '0': 6847, '8': 7, '210': 13, '77': 1, '9': 1}

# %%
#question 7
#Distinct passenger_count:
import csv
data = 'trip_data_6.csv'

f = open(data, 'r')
reader = csv.reader(f)
passenger_count = {}

i=0
n=0

for row in reader:
     if i>0:
        k = row[7]
        if k in passenger_count:
             passenger_count[k] += 1
        else:
             passenger_count[k] = 1
        if n % 500000 == 0:
             print(n)
        n+=1
     i+=1

print(passenger_count)
# Out:
# 0
# 500000
# 1000000
# 1500000
# 2000000
# 2500000
# 3000000
# 3500000
# 4000000
# 4500000
# 5000000
# 5500000
# 6000000
# 6500000
# 7000000
# 7500000
# 8000000
# 8500000
# 9000000
# 9500000
# 10000000
# 10500000
# 11000000
# 11500000
# 12000000
# 12500000
# 13000000
# 13500000
# 14000000
# {'1': 10091826, '2': 1941858, '3': 620138, '4': 303352, '5': 845641, '6': 582146, '0': 490, '8': 4, '208': 1}

# %%
# Question 8
data = 'trip_data_6.csv'
f= open(data, 'r')
reader = csv.reader(f)


n = 0
for row in reader:
    if n==1:
        rate_code_min = int(row[3])
        rate_code_max = int(row[3])
        passenger_count_min = int(row[7])
        passenger_count_max = int(row[7])
        trip_time_min = int(row[8])
        trip_time_max = int(row[8])
        trip_distance_min = float(row[9])
        trip_distance_max = float(row[9])
    elif n > 1:
        try:
            rate_code=int(row[3])
            passenger_count = int(row[7])
            trip_time = int(row[8])
            trip_distance = float(row[9])
        except Exception as e:
            print(e)     
            
        if rate_code<rate_code_min:
            rate_code_min=rate_code
        elif rate_code>rate_code_max:
            rate_code_max=rate_code
        
        if passenger_count<passenger_count_min:
            passenger_count_min=passenger_count
        elif passenger_count>passenger_count_max:
            passenger_count_max=passenger_count
            
        if trip_time<trip_time_min:
            trip_time_min=trip_time
        elif trip_time>trip_time_max:
            trip_time_max=trip_time
            
        if trip_distance<trip_distance_min:
            trip_distance_min=trip_distance
        elif trip_distance>trip_distance_max:
            trip_distance_max=trip_distance
            
    
    if n % 500000 == 0:
        print(n)
    n+=1

print('min rate code=',rate_code_min,'max rate code=',rate_code_max)
print('min passenger count=',passenger_count_min,'max passenger count=',passenger_count_max)
print('min trip time=',trip_time_min,'max trip time=',trip_time_max)
print('min trip distance=',trip_distance_min,'max trip distance=',trip_distance_max)
# Out:
# 0
# 500000
# 1000000
# 1500000
# 2000000
# 2500000
# 3000000
# 3500000
# 4000000
# 4500000
# 5000000
# 5500000
# 6000000
# 6500000
# 7000000
# 7500000
# 8000000
# 8500000
# 9000000
# 9500000
# 10000000
# 10500000
# 11000000
# 11500000
# 12000000
# 12500000
# 13000000
# 13500000
# 14000000
# min rate code= 0 max rate code= 210
# min passenger count= 0 max passenger count= 208
# min trip time= 0 max trip time= 10800
# min trip distance= 0.0 max trip distance= 100.0

# %%
#Question 9:
#Creating a new CSV:
import csv, datetime
from datetime import timedelta
data = 'trip_data_6.csv'

f = open(data, 'r')
reader = csv.reader(f)
minval = None
maxval = None
n = 0

hours={i:0 for i in range(0,24)}

for row in reader:
    if n > 0:
        dto = None
        dts_pickup = row[5]
        try:
            a = datetime.datetime.strptime(dts_pickup,"%Y-%m-%d %H:%M:%S")
            dto = a.strftime('%Y-%m-%d')
            hour_pickup= int(a.strftime('%H'))
            hours[hour_pickup]+=int(row[7])


        except Exception as e:
            print(e)
        if dto is not None:
            if maxval is None or dto > maxval:
                maxval = dto
            if minval is None or dto < minval:
                minval = dto 
           

    
    if n % 50000 == 0:
        print(n)
    n+=1

print(n)



print('min_pickup_date:',minval, 'max_pickup_date:',maxval)
mnpd = datetime.datetime.strptime(minval,"%Y-%m-%d")
mxpd = datetime.datetime.strptime(maxval,"%Y-%m-%d")
dpd=mxpd-mnpd
days= dpd.days

for v in hours:
    hours[v]/=days

print(hours)

import matplotlib.pyplot as plt


names = list(hours.keys())
values = list(hours.values())

plt.bar(range(len(hours)), values, tick_label=names)
plt.xlabel('Hours')
plt.ylabel('Average Passengers')
plt.savefig('Average_Passengers.jpg')
# Out:
# 0
# 50000
# 100000
# 150000
# 200000
# 250000
# 300000
# 350000
# 400000
# 450000
# 500000
# 550000
# 600000
# 650000
# 700000
# 750000
# 800000
# 850000
# 900000
# 950000
# 1000000
# 1050000
# 1100000
# 1150000
# 1200000
# 1250000
# 1300000
# 1350000
# 1400000
# 1450000
# 1500000
# 1550000
# 1600000
# 1650000
# 1700000
# 1750000
# 1800000
# 1850000
# 1900000
# 1950000
# 2000000
# 2050000
# 2100000
# 2150000
# 2200000
# 2250000
# 2300000
# 2350000
# 2400000
# 2450000
# 2500000
# 2550000
# 2600000
# 2650000
# 2700000
# 2750000
# 2800000
# 2850000
# 2900000
# 2950000
# 3000000
# 3050000
# 3100000
# 3150000
# 3200000
# 3250000
# 3300000
# 3350000
# 3400000
# 3450000
# 3500000
# 3550000
# 3600000
# 3650000
# 3700000
# 3750000
# 3800000
# 3850000
# 3900000
# 3950000
# 4000000
# 4050000
# 4100000
# 4150000
# 4200000
# 4250000
# 4300000
# 4350000
# 4400000
# 4450000
# 4500000
# 4550000
# 4600000
# 4650000
# 4700000
# 4750000
# 4800000
# 4850000
# 4900000
# 4950000
# 5000000
# 5050000
# 5100000
# 5150000
# 5200000
# 5250000
# 5300000
# 5350000
# 5400000
# 5450000
# 5500000
# 5550000
# 5600000
# 5650000
# 5700000
# 5750000
# 5800000
# 5850000
# 5900000
# 5950000
# 6000000
# 6050000
# 6100000
# 6150000
# 6200000
# 6250000
# 6300000
# 6350000
# 6400000
# 6450000
# 6500000
# 6550000
# 6600000
# 6650000
# 6700000
# 6750000
# 6800000
# 6850000
# 6900000
# 6950000
# 7000000
# 7050000
# 7100000
# 7150000
# 7200000
# 7250000
# 7300000
# 7350000
# 7400000
# 7450000
# 7500000
# 7550000
# 7600000
# 7650000
# 7700000
# 7750000
# 7800000
# 7850000
# 7900000
# 7950000
# 8000000
# 8050000
# 8100000
# 8150000
# 8200000
# 8250000
# 8300000
# 8350000
# 8400000
# 8450000
# 8500000
# 8550000
# 8600000
# 8650000
# 8700000
# 8750000
# 8800000
# 8850000
# 8900000
# 8950000
# 9000000
# 9050000
# 9100000
# 9150000
# 9200000
# 9250000
# 9300000
# 9350000
# 9400000
# 9450000
# 9500000
# 9550000
# 9600000
# 9650000
# 9700000
# 9750000
# 9800000
# 9850000
# 9900000
# 9950000
# 10000000
# 10050000
# 10100000
# 10150000
# 10200000
# 10250000
# 10300000
# 10350000
# 10400000
# 10450000
# 10500000
# 10550000
# 10600000
# 10650000
# 10700000
# 10750000
# 10800000
# 10850000
# 10900000
# 10950000
# 11000000
# 11050000
# 11100000
# 11150000
# 11200000
# 11250000
# 11300000
# 11350000
# 11400000
# 11450000
# 11500000
# 11550000
# 11600000
# 11650000
# 11700000
# 11750000
# 11800000
# 11850000
# 11900000
# 11950000
# 12000000
# 12050000
# 12100000
# 12150000
# 12200000
# 12250000
# 12300000
# 12350000
# 12400000
# 12450000
# 12500000
# 12550000
# 12600000
# 12650000
# 12700000
# 12750000
# 12800000
# 12850000
# 12900000
# 12950000
# 13000000
# 13050000
# 13100000
# 13150000
# 13200000
# 13250000
# 13300000
# 13350000
# 13400000
# 13450000
# 13500000
# 13550000
# 13600000
# 13650000
# 13700000
# 13750000
# 13800000
# 13850000
# 13900000
# 13950000
# 14000000
# 14050000
# 14100000
# 14150000
# 14200000
# 14250000
# 14300000
# 14350000
# 14385457
# min_pickup_date: 2013-06-01 max_pickup_date: 2013-06-30
# {0: 38590.41379310345, 1: 28269.655172413793, 2: 21402.793103448275, 3: 15293.448275862069, 4: 10785.379310344828, 5: 8406.586206896553, 6: 16173.068965517241, 7: 28487.758620689656, 8: 35925.34482758621, 9: 37950.862068965514, 10: 37594.275862068964, 11: 39463.89655172414, 12: 41280.206896551725, 13: 40923.34482758621, 14: 41958.44827586207, 15: 39847.137931034486, 16: 32822.137931034486, 17: 39888.41379310345, 18: 49599.1724137931, 19: 53209.379310344826, 20: 49892.724137931036, 21: 50870.0, 22: 49684.51724137931, 23: 45842.58620689655}

# %%
#Question 10:
#Creating a new CSV:

import csv

data = 'trip_data_6.csv'

new_csv='new_dataset6.csv'

f = open(data, 'r')
reader = csv.reader(f)

n=0
f= open('new_dataset6.csv', 'w', newline='')
writer = csv.writer(f)

for row in reader:
    if n>0:
        if n % 500000 == 0:
             print(n)
        if n%1000==1:
            writer.writerow(row)
    else:
        writer.writerow(row)

    n+=1

f.close()
# Out:
# 500000
# 1000000
# 1500000
# 2000000
# 2500000
# 3000000
# 3500000
# 4000000
# 4500000
# 5000000
# 5500000
# 6000000
# 6500000
# 7000000
# 7500000
# 8000000
# 8500000
# 9000000
# 9500000
# 10000000
# 10500000
# 11000000
# 11500000
# 12000000
# 12500000
# 13000000
# 13500000
# 14000000

# %%
#Question 11 :

import csv, datetime
from datetime import timedelta
data_new = 'new_dataset6.csv'

f_new = open(data_new, 'r')
reader_new = csv.reader(f_new)
minval_new = None
maxval_new = None
n = 0

hours={i:0 for i in range(0,24)}

for row in reader_new:
    if n > 0:
        dto_new = None
        dts_pickup_new = row[5]
        try:
            a = datetime.datetime.strptime(dts_pickup_new,"%Y-%m-%d %H:%M:%S")
            dto_new = a.strftime('%Y-%m-%d %H:%M:%S')
            hour_pickup_new= int(a.strftime('%H'))
            hours[hour_pickup_new]+=int(row[7])


        except Exception as e:
            print(e)
        if dto_new is not None:
            if maxval_new is None or dto_new > maxval_new:
                maxval_new = dto_new
            if minval_new is None or dto_new < minval_new:
                minval_new = dto_new 
           

    
    if n % 50000 == 0:
        print(n)
    n+=1

print(n)

print('min_pickup_date_new:',minval_new, 'max_pickup_date_new:',maxval_new)
mnpd = datetime.datetime.strptime(minval_new,"%Y-%m-%d %H:%M:%S")
mxpd = datetime.datetime.strptime(maxval_new,"%Y-%m-%d %H:%M:%S")
dpd=mxpd-mnpd
days=dpd.days

for v in hours:
    hours[v]/=days

print(hours)

import matplotlib.pyplot as plt


names = list(hours.keys())
values = list(hours.values())

plt.bar(range(len(hours)), values, tick_label=names)
plt.xlabel('Hours')
plt.ylabel('Average Passengers')
plt.savefig('Average_Passengers_new.jpg')
# Out:
# 0
# 14387
# min_pickup_date_new: 2013-06-01 00:01:43 max_pickup_date_new: 2013-06-30 23:58:00
# {0: 39.689655172413794, 1: 29.24137931034483, 2: 20.862068965517242, 3: 15.275862068965518, 4: 9.448275862068966, 5: 8.931034482758621, 6: 15.689655172413794, 7: 30.03448275862069, 8: 36.172413793103445, 9: 37.310344827586206, 10: 37.89655172413793, 11: 41.41379310344828, 12: 41.275862068965516, 13: 37.827586206896555, 14: 43.96551724137931, 15: 42.172413793103445, 16: 32.44827586206897, 17: 37.6551724137931, 18: 49.6551724137931, 19: 52.0, 20: 51.206896551724135, 21: 53.06896551724138, 22: 48.41379310344828, 23: 44.275862068965516}
